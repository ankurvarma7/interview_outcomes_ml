# %%
# %run xgboost_model.py
# Out:
# Mean Absolute Relative Error: 0.0799
# Pearson: 0.3131 (p-value: 0.09202)
# Mean Absolute Relative Error: 0.1199
# Pearson: 0.1514 (p-value: 0.4245)
# Mean Absolute Relative Error: 0.0827
# Pearson: 0.2952 (p-value: 0.1132)
# Mean Absolute Relative Error: 0.1018
# Pearson: 0.3711 (p-value: 0.04351)
